# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
data = pd.read_csv("Challenger_Ranked_Games_10minute.csv")
data
# Out:
#            gameId  blueWins  blueTotalGolds  blueCurrentGolds  blueTotalLevel  \
# 0      4247263043         0           14870              2889              32
# 1      4247155821         1           14497              2617              33
# 2      4243963257         0           15617              1757              34
# 3      4241678498         0           15684              1439              35
# 4      4241538868         1           17472              3512              35
# ...           ...       ...             ...               ...             ...
# 26404  4143231833         0           16762              5072              36
# 26405  4157911901         0           35765              1440              39
# 26406  3764171638         0           15712              4137              34
# 26407  4110201724         1           15850              3220              33
# 26408  4100240254         1           16103              3128              34
#
# ...

# %%
data.shape
# Out:
# (26409, 51)

# %%
data.sum(axis=0)
# Out:
# gameId                                                          110170251783556
# blueWins                                                                  13234
# blueTotalGolds                                                        480367837
# blueCurrentGolds                                                       82784626
# blueTotalLevel                                                           957527
# blueAvgLevel                                                             191505
# blueTotalMinionKills                                                    5647624
# blueTotalJungleMinionKills                                              1223085
# blueFirstBlood                                                                0
# blueKill                                                                 202408
# blueDeath                                                                202069
# blueAssist                                                               281356
# ...

# %%
data.mean()
# Out:
# gameId                        4.171693e+09
# blueWins                      5.011170e-01
# blueTotalGolds                1.818955e+04
# blueCurrentGolds              3.134713e+03
# blueTotalLevel                3.625760e+01
# blueAvgLevel                  7.251520e+00
# blueTotalMinionKills          2.138522e+02
# blueTotalJungleMinionKills    4.631319e+01
# blueFirstBlood                0.000000e+00
# blueKill                      7.664357e+00
# blueDeath                     7.651520e+00
# blueAssist                    1.065379e+01
# blueWardPlaced                2.154451e+01
# blueWardKills                 3.885115e+00
# blueFirstTower                7.111212e-02
# blueFirstInhibitor            6.172138e-03
# blueTowerKills                1.224961e-01
# blueMidTowerKills             6.520504e-02
# blueTopTowerKills             3.161801e-02
# blueBotTowerKills             2.567307e-02
# blueInhibitor                 6.210004e-03
# blueFirstDragon               3.045174e-01
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26409 entries, 0 to 26408
# Data columns (total 51 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   gameId                      26409 non-null  int64
#  1   blueWins                    26409 non-null  int64
#  2   blueTotalGolds              26409 non-null  int64
#  3   blueCurrentGolds            26409 non-null  int64
#  4   blueTotalLevel              26409 non-null  int64
#  5   blueAvgLevel                26409 non-null  float64
#  6   blueTotalMinionKills        26409 non-null  int64
#  7   blueTotalJungleMinionKills  26409 non-null  int64
#  8   blueFirstBlood              26409 non-null  int64
#  9   blueKill                    26409 non-null  int64
#  10  blueDeath                   26409 non-null  int64
#  11  blueAssist                  26409 non-null  int64
#  12  blueWardPlaced              26409 non-null  int64
# ...

# %%
data= data.drop(['gameId',redFirstBlood,])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-81ea01f194a2> in <module>
# ----> 1 data= data.drop(['gameId',redFirstBlood,])
#
# NameError: name 'redFirstBlood' is not defined

# %%
corr=data.corr()
plt.figure(figsize=(20, 20))
sns.heatmap(corr,cmap="mako", annot=True, fmt='.2f', vmin=0)
# Out:
# <AxesSubplot:>
